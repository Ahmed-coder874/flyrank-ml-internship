# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-coder874/flyrank-ml-internship/blob/main/work/%20FL-02_Portfolio_Sitemap_Toolkit_Sheik_Ahmed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FL-02: Draw the Path - Portfolio Sitemap + Toolkit
#
# ## My Portfolio Goal
#
# My goal is to create a personal AI/ML portfolio that demonstrates my skills, projects, and ability to build practical AI solutions.
#
# ## My Proof Statement
#
# I am an aspiring AI/ML engineer building practical projects using machine learning, data analysis, and AI tools. My portfolio will show my projects, learning journey, and technical skills.

# %% [markdown]
# Home
#  |
#  |-- Projects / Case Studies
#  |
#  |-- About Me
#  |
#  |-- Contact

# %% [markdown]
#           Sheik Ahmed AI Portfolio
#
#                     |
#                   Home
#
#         ____________|____________
#
#        |            |            |
#
#    Projects       About       Contact

# %% [markdown]
# # Portfolio Sitemap Explanation
#
# ## Home
# The landing page explains who I am and what type of AI/ML work I create.
#
# ## Projects
# This page provides evidence of my skills through case studies and GitHub projects.
#
# ## About Me
# This page explains my background, skills, and learning goals.
#
# ## Contact
# This page provides a way for visitors to connect with me.
