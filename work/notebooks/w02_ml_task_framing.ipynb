# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-coder874/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ahmed-coder874/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# My lane is a scoring/ranking problem.
#
# The goal is to create an opportunity score for content pages based on historical performance data. This score helps rank pages by their potential need for optimization.
#
# This is a scoring problem because the output is a priority score that allows the content team to decide which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# The target is predicting which content pages have a higher opportunity for improvement.
#
# A proxy label can be created from observed historical outcomes, such as trend_direction showing whether a page has declined or improved over time.
#
# The label comes from historical page performance data, not from assumptions about how search engines work.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# The success metric is Precision@50.
#
# This measures how many of the top 50 pages recommended by the model are actually pages with a refresh opportunity.
#
# A higher Precision@50 means the model is better at helping the content team prioritize useful pages.
#
# From the starter pipeline:
# Random Forest Precision@50 = 0.740
# Baseline Precision@50 = 0.240

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# The unit of analysis is one content page.
#
# Each row represents one page and contains historical signals such as impressions, click-through rate, ranking position, content information, and trend direction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df[[
    "content_id",
    "impressions_90d",
    "ctr",
    "avg_position",
    "trend_direction"
]].head()
# Out:
#              content_id  impressions_90d   ctr  avg_position trend_direction
# 0  content_304f48230142             3803  0.76          10.6            down
# 1  content_a1fb4e703a9e            15320  0.05          20.3            down
# 2  content_9aa793d4d895            12581  0.09          36.5            down
# 3  content_331d6c4de07b            11751  0.49           6.2          stable
# 4  content_d99b7a2d90ca            19140  0.13          44.0            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule would only consider a small number of conditions, such as traffic decline or ranking position.
#
# Content performance depends on many signals working together, including impressions, CTR, position, competition, and content characteristics.
#
# Machine learning can combine multiple signals and identify patterns that are difficult to capture with a simple if-else rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
import os
import sys
import subprocess

REPO_URL = "https://github.com/Ahmed-coder874/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print("Current folder:", os.getcwd())
# Out:
# Current folder: /content/flyrank-ml-internship

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True
