# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-coder874/flyrank-ml-internship/blob/main/work/FL_04_Frame_It_As_Cases_Sheik_Ahmed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FL-04: Frame It as Cases - Work That Speaks for Itself
#
# ## Voice Card
#
# Clear, technical, practical, beginner-friendly, honest, focused.
#
# My portfolio voice should communicate real work without unnecessary buzzwords.

# %% [markdown]
# # Case Study 1: FlyRank ML Internship Capstone
#
# ## Problem
#
# Understanding search and content performance requires analyzing large amounts of data and identifying meaningful patterns.
#
# ## What I Did
#
# I built a machine learning analysis workflow using the FlyRank internship dataset.
#
# I explored the data, created features, developed a baseline approach, trained ML models, evaluated results, and converted findings into ranked recommendations.
#
# I focused on building a reliable decision-support system rather than making unsupported claims.
#
# ## What Came Of It
#
# The project produced a structured analysis workflow and ranked recommendations that can help prioritize content opportunities.
#
# The experience improved my skills in machine learning, data analysis, validation, and communicating technical results.

# %% [markdown]
# # Case Study 2: AI Portfolio Assistant
#
# ## Problem
#
# Recruiters and visitors often need a quick way to understand my skills, projects, and experience.
#
# ## What I Did
#
# I designed the idea of a personal AI assistant that can answer questions about my background, projects, and technical skills.
#
# The assistant uses my portfolio information as knowledge and provides a conversational way for visitors to learn about my work.
#
# ## What Came Of It
#
# This project demonstrates how AI can improve user interaction and make technical portfolios more accessible.

# %% [markdown]
# # Case Study 3: V Care Computers Website
#
# ## Problem
#
# Small businesses need an online presence where customers can understand their services and contact them easily.
#
# ## What I Did
#
# I developed a web solution focused on presenting services clearly through a user-friendly interface.
#
# I worked on website structure, design, and creating an accessible user experience.
#
# ## What Came Of It
#
# The project improved my understanding of frontend development, user experience, and building websites for real-world needs.

# %% [markdown]
# # Bio
#
# I am Sheik Ahmed, an Information Science and Engineering student interested in Artificial Intelligence, Machine Learning, and software development.
#
# I enjoy building practical technology solutions that combine intelligent systems with good software engineering practices.
#
# # Contact / Call To Action
#
# Interested in AI, ML, or software development projects?
#
# Connect with me to discuss opportunities and collaborations.
#
# GitHub:
# https://github.com/Ahmed-coder874
#
# Email:
# sheikahmedmuzammil@gmail.com

# %% [markdown]
# # Before and After Editing Example
#
# ## Generic AI Version
#
# "I am a passionate and results-driven AI enthusiast who leverages cutting-edge technologies to create innovative solutions."
#
# ## My Edited Version
#
# "I am an Information Science and Engineering student building practical AI and software projects. I focus on learning, experimenting, and creating solutions that solve real problems."
