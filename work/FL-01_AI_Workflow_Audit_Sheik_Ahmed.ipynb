# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-coder874/flyrank-ml-internship/blob/main/work/FL-01_AI_Workflow_Audit_Sheik_Ahmed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FL-01: AI Workflow Audit and Tool Setup
#
# **Name:** Sheik Ahmed
#
# **Track:** General AI Fluency
#
# ## Purpose
#
# This document maps my recurring tasks and identifies where AI can assist, collaborate, or should not be used.

# %% [markdown]
# # 1. Workflow Audit
#
# | Task | Category | Reason |
# |---|---|---|
# | Learning Python and Machine Learning concepts | Collaborate with AI | AI can explain concepts and provide examples while I verify my understanding |
# | Debugging Python errors | Delegate to AI with review | AI can suggest solutions, but I test and understand the fix |
# | Writing project documentation | Delegate to AI with review | AI helps improve structure and clarity |
# | Researching AI tools | Collaborate with AI | AI helps summarize and compare different tools |
# | Brainstorming project ideas | Collaborate with AI | AI helps generate ideas, but I make the final decision |
# | Preparing presentations | Delegate to AI with review | AI helps organize information |
# | Writing professional messages | Delegate to AI with review | AI improves grammar and tone |
# | Practicing interview questions | Collaborate with AI | AI acts as a practice partner |
# | Reviewing my personal career goals | Just me | Requires personal reflection and decisions |
# | Choosing long-term career direction | Just me | Requires my own judgment |
# | Managing GitHub projects | Collaborate with AI | AI can suggest improvements |
# | Studying mathematics for ML | Collaborate with AI | AI helps explain difficult concepts |

# %% [markdown]
# # 2. Three AI Tasks I Will Reuse
#
# ## Task 1: Learning ML Concepts
#
# **How AI helps:**
# AI explains difficult topics, gives examples, and creates practice questions.
#
# **Success definition:**
# - I can explain the concept in my own words.
# - I can solve practice problems.
# - I can create a small implementation.
#
#
# ## Task 2: Coding Assistance
#
# **How AI helps:**
# AI assists with debugging, improving code quality, and explaining errors.
#
# **Success definition:**
# - The code runs correctly.
# - I understand the changes.
# - I can explain the solution.
#
#
# ## Task 3: Technical Writing
#
# **How AI helps:**
# AI improves documentation, reports, and project explanations.
#
# **Success definition:**
# - The document has a clear structure.
# - The explanation is understandable.
# - Another person can follow the project.

# %% [markdown]
# # 3. AI Tool Setup
#
# ## Tools Setup
#
# I created and configured:
#
# - ChatGPT account
# - Claude account
# - Anthropic Academy account
#
# ## Claude Project Configuration
#
# Project Name:
#
# Sheik Ahmed AI Assistant
#
# Purpose:
#
# A personal AI assistant that helps me learn AI concepts, improve my projects, and develop better workflows.

# %% [markdown]
# # Conclusion
#
# This audit helped me understand which tasks benefit from AI assistance and which tasks require my own judgment.
#
# I will use AI as a collaborator and productivity tool while maintaining human review and responsibility.
